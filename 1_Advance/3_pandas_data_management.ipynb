# %% [markdown]
# #### **Data Management**

# %%
#importing lib
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
#load data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
#data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# README.md:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# d:\Anaconda\envs\python_course\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Manoj Gogoi\.cache\huggingface\hub\datasets--lukebarousse--data_jobs. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df.sample(10)
# Out:
#               job_title_short                                     job_title  \
# 286661         Data Scientist  Data Scientist (DoD Clearance required) Jobs
# 494460          Data Engineer                            Lead Data Engineer
# 350127           Data Analyst                                  Data Analyst
# 454023    Senior Data Analyst             SAINT LAURENT Senior Data Analyst
# 713872  Senior Data Scientist                         Senior Data Scientist
# 584750      Software Engineer  Software Engineer [fullstack, backend, data]
# 351352      Software Engineer                          Application Engineer
# 165216          Data Engineer                       Principal Data Engineer
# 61439       Software Engineer                      Backend Engineering Lead
# 210027         Data Scientist                        Data Scientist, Poland
#
#                                         job_location                job_via  \
# 286661                                Fort Bragg, NC     via Clearance Jobs
# 494460                                 Baltimore, MD              via Jobg8
# 350127             Makati, Metro Manila, Philippines             via Jooble
# 454023                                     Hong Kong           via BeBee 香港
# 713872                                      Virginia        via SimplyHired
# 584750                                      Anywhere           via Remotely
# 351352                                       Denmark        via Trabajo.org
# 165216                                      Anywhere           via LinkedIn
# 61439   Tangerang, Tangerang City, Banten, Indonesia        via Trabajo.org
# 210027                                Warsaw, Poland  via Praca Trabajo.org
#
#               job_schedule_type  job_work_from_home  \
# 286661                Full-time               False
# 494460  Full-time and Part-time               False
# 350127                Full-time               False
# 454023                Full-time               False
# 713872                Full-time               False
# 584750                Full-time                True
# 351352                Full-time               False
# 165216                Full-time                True
# 61439                 Full-time               False
# 210027                Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 286661                    Georgia 2023-03-11 18:08:10                  False
# 494460    Illinois, United States 2023-12-28 11:27:40                  False
# 350127                Philippines 2023-07-09 23:52:38                  False
# 454023                  Hong Kong 2023-03-24 14:56:39                  False
# 713872    New York, United States 2023-10-20 02:23:10                  False
# 584750                      Spain 2023-05-09 09:39:34                  False
# 351352                    Denmark 2023-05-01 23:21:31                   True
# 165216  California, United States 2023-12-14 15:06:09                  False
# 61439                   Indonesia 2023-12-12 06:38:59                  False
# 210027                     Poland 2023-06-08 22:37:36                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 286661                  True  United States        None              NaN
# 494460                  True  United States        None              NaN
# 350127                 False    Philippines        None              NaN
# 454023                 False      Hong Kong        None              NaN
# 713872                 False  United States        None              NaN
# 584750                 False          Spain        None              NaN
# 351352                 False        Denmark        None              NaN
# 165216                 False  United States        None              NaN
# 61439                  False      Indonesia        None              NaN
# 210027                 False         Poland        None              NaN
#
#         salary_hour_avg                  company_name  \
# 286661              NaN  Zachary Piper Solutions, LLC
# 494460              NaN             Jobs for Humanity
# 350127              NaN                     Metrobank
# 454023              NaN        Yves Saint Laurent SAS
# 713872              NaN                  M9 Solutions
# 584750              NaN                      Capchase
# 351352              NaN                      CCV GmbH
# 165216              NaN                          Dice
# 61439               NaN  PT BFI Finance Indonesia Tbk
# 210027              NaN                  Surprise.com
#
#                                                job_skills  \
# 286661  ['python', 'r', 'golang', 'javascript', 'pytor...
# 494460  ['java', 'scala', 'python', 'sql', 'nosql', 'a...
# 350127                         ['sas', 'sas', 'power bi']
# 454023  ['python', 'r', 'sql', 'sas', 'sas', 'bigquery...
# 713872                            ['databricks', 'azure']
# 584750   ['go', 'elixir', 'python', 'gitlab', 'airtable']
# 351352                                               None
# 165216  ['scala', 'mongodb', 'mongodb', 'nosql', 'java...
# 61439                            ['go', 'java', 'spring']
# 210027  ['python', 'sql', 'snowflake', 'redshift', 'sp...
#
#                                           job_type_skills
# 286661  {'libraries': ['pytorch'], 'other': ['git', 'k...
# 494460  {'cloud': ['aws', 'redshift', 'snowflake', 'az...
# 350127  {'analyst_tools': ['sas', 'power bi'], 'progra...
# 454023  {'analyst_tools': ['sas', 'tableau', 'power bi...
# 713872                 {'cloud': ['databricks', 'azure']}
# 584750  {'async': ['airtable'], 'other': ['gitlab'], '...
# 351352                                               None
# 165216  {'cloud': ['aws'], 'databases': ['mongodb', 'd...
# 61439   {'libraries': ['spring'], 'programming': ['go'...
# 210027  {'analyst_tools': ['tableau'], 'cloud': ['snow...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
#COPY Method helps experimenting with the dataset without changing the original dataset
df_altered = df_original.copy()

# %%
print('ID of ogriginal:',id(df_original))
print('ID of altered:',id(df_altered))
# Out:
# ID of ogriginal: 2914971999312
# ID of altered: 2914682234768

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
